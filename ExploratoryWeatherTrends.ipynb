# %%
# Importing Libraries
import numpy as np
import pandas as pd

# %%
# reading City_Data Dataset
df1 = pd.read_csv('dataset/city_data.csv')
df1.head()
# Out:
#    year     city        country  avg_temp
# 0  1849  Abidjan  Côte D'Ivoire     25.58
# 1  1850  Abidjan  Côte D'Ivoire     25.52
# 2  1851  Abidjan  Côte D'Ivoire     25.67
# 3  1852  Abidjan  Côte D'Ivoire       NaN
# 4  1853  Abidjan  Côte D'Ivoire       NaN

# %%
# Replacing "" value for Nan
df1.replace("",np.nan)
# Out:
#        year     city        country  avg_temp
# 0      1849  Abidjan  Côte D'Ivoire     25.58
# 1      1850  Abidjan  Côte D'Ivoire     25.52
# 2      1851  Abidjan  Côte D'Ivoire     25.67
# 3      1852  Abidjan  Côte D'Ivoire       NaN
# 4      1853  Abidjan  Côte D'Ivoire       NaN
# 5      1854  Abidjan  Côte D'Ivoire       NaN
# 6      1855  Abidjan  Côte D'Ivoire       NaN
# 7      1856  Abidjan  Côte D'Ivoire     26.28
# 8      1857  Abidjan  Côte D'Ivoire     25.17
# 9      1858  Abidjan  Côte D'Ivoire     25.49
# 10     1859  Abidjan  Côte D'Ivoire     25.92
# 11     1860  Abidjan  Côte D'Ivoire     25.46
# 12     1861  Abidjan  Côte D'Ivoire     25.67
# 13     1862  Abidjan  Côte D'Ivoire     25.17
# 14     1863  Abidjan  Côte D'Ivoire       NaN
# 15     1864  Abidjan  Côte D'Ivoire       NaN
# 16     1865  Abidjan  Côte D'Ivoire       NaN
# 17     1866  Abidjan  Côte D'Ivoire       NaN
# 18     1867  Abidjan  Côte D'Ivoire       NaN
# ...

# %%
# Deleting Nan rows
df1.dropna(subset = ['avg_temp'], inplace=True)
df1
# Out:
#        year     city        country  avg_temp
# 0      1849  Abidjan  Côte D'Ivoire     25.58
# 1      1850  Abidjan  Côte D'Ivoire     25.52
# 2      1851  Abidjan  Côte D'Ivoire     25.67
# 7      1856  Abidjan  Côte D'Ivoire     26.28
# 8      1857  Abidjan  Côte D'Ivoire     25.17
# 9      1858  Abidjan  Côte D'Ivoire     25.49
# 10     1859  Abidjan  Côte D'Ivoire     25.92
# 11     1860  Abidjan  Côte D'Ivoire     25.46
# 12     1861  Abidjan  Côte D'Ivoire     25.67
# 13     1862  Abidjan  Côte D'Ivoire     25.17
# 24     1873  Abidjan  Côte D'Ivoire     25.62
# 25     1874  Abidjan  Côte D'Ivoire     25.68
# 26     1875  Abidjan  Côte D'Ivoire     25.25
# 27     1876  Abidjan  Côte D'Ivoire     25.14
# 28     1877  Abidjan  Côte D'Ivoire     25.85
# 29     1878  Abidjan  Côte D'Ivoire     25.87
# 30     1879  Abidjan  Côte D'Ivoire     25.38
# 31     1880  Abidjan  Côte D'Ivoire     25.96
# 32     1881  Abidjan  Côte D'Ivoire     26.07
# ...

# %%
df1.dropna(subset = ['country'], inplace=True)
df1
# Out:
#        year     city        country  avg_temp
# 0      1849  Abidjan  Côte D'Ivoire     25.58
# 1      1850  Abidjan  Côte D'Ivoire     25.52
# 2      1851  Abidjan  Côte D'Ivoire     25.67
# 7      1856  Abidjan  Côte D'Ivoire     26.28
# 8      1857  Abidjan  Côte D'Ivoire     25.17
# 9      1858  Abidjan  Côte D'Ivoire     25.49
# 10     1859  Abidjan  Côte D'Ivoire     25.92
# 11     1860  Abidjan  Côte D'Ivoire     25.46
# 12     1861  Abidjan  Côte D'Ivoire     25.67
# 13     1862  Abidjan  Côte D'Ivoire     25.17
# 24     1873  Abidjan  Côte D'Ivoire     25.62
# 25     1874  Abidjan  Côte D'Ivoire     25.68
# 26     1875  Abidjan  Côte D'Ivoire     25.25
# 27     1876  Abidjan  Côte D'Ivoire     25.14
# 28     1877  Abidjan  Côte D'Ivoire     25.85
# 29     1878  Abidjan  Côte D'Ivoire     25.87
# 30     1879  Abidjan  Côte D'Ivoire     25.38
# 31     1880  Abidjan  Côte D'Ivoire     25.96
# 32     1881  Abidjan  Côte D'Ivoire     26.07
# ...

# %%
# Reading Global_Data Dataset
df2 = pd.read_csv('dataset/global_data.csv')
df2.head()
# Out:
#    year  avg_temp
# 0  1750      8.72
# 1  1751      7.98
# 2  1752      5.78
# 3  1753      8.39
# 4  1754      8.47

# %%
# Replacing "" value for Nan 
df2.replace("",np.nan)
# Out:
#      year  avg_temp
# 0    1750      8.72
# 1    1751      7.98
# 2    1752      5.78
# 3    1753      8.39
# 4    1754      8.47
# 5    1755      8.36
# 6    1756      8.85
# 7    1757      9.02
# 8    1758      6.74
# 9    1759      7.99
# 10   1760      7.19
# 11   1761      8.77
# 12   1762      8.61
# 13   1763      7.50
# 14   1764      8.40
# 15   1765      8.25
# 16   1766      8.41
# 17   1767      8.22
# 18   1768      6.78
# 19   1769      7.69
# 20   1770      7.69
# 21   1771      7.85
# 22   1772      8.19
# 23   1773      8.22
# 24   1774      8.77
# 25   1775      9.18
# 26   1776      8.30
# 27   1777      8.26
# 28   1778      8.54
# 29   1779      8.98
# ..    ...       ...
# 236  1986      8.83
# 237  1987      8.99
# 238  1988      9.20
# 239  1989      8.92
# 240  1990      9.23
# 241  1991      9.18
# 242  1992      8.84
# 243  1993      8.87
# 244  1994      9.04
# 245  1995      9.35
# 246  1996      9.04
# 247  1997      9.20
# 248  1998      9.52
# ...

# %%
# Deleting Nan rows in the avg_temp column
df2.dropna(subset = ['avg_temp'], inplace=True)

# %%
df2['city'] = 'Global'

# %%
df2['country'] = 'Global'

# %%
df2
# Out:
#      year  avg_temp    city country
# 0    1750      8.72  Global  Global
# 1    1751      7.98  Global  Global
# 2    1752      5.78  Global  Global
# 3    1753      8.39  Global  Global
# 4    1754      8.47  Global  Global
# 5    1755      8.36  Global  Global
# 6    1756      8.85  Global  Global
# 7    1757      9.02  Global  Global
# 8    1758      6.74  Global  Global
# 9    1759      7.99  Global  Global
# 10   1760      7.19  Global  Global
# 11   1761      8.77  Global  Global
# 12   1762      8.61  Global  Global
# 13   1763      7.50  Global  Global
# 14   1764      8.40  Global  Global
# 15   1765      8.25  Global  Global
# 16   1766      8.41  Global  Global
# 17   1767      8.22  Global  Global
# 18   1768      6.78  Global  Global
# 19   1769      7.69  Global  Global
# 20   1770      7.69  Global  Global
# 21   1771      7.85  Global  Global
# 22   1772      8.19  Global  Global
# 23   1773      8.22  Global  Global
# 24   1774      8.77  Global  Global
# ...

# %%
# Concatenating datasets
df1 = df1.append(df2, ignore_index=True)

df1.head(5)
# Out:
#        avg_temp     city        country  year
# 0         25.58  Abidjan  Côte D'Ivoire  1849
# 1         25.52  Abidjan  Côte D'Ivoire  1850
# 2         25.67  Abidjan  Côte D'Ivoire  1851
# 3         26.28  Abidjan  Côte D'Ivoire  1856
# 4         25.17  Abidjan  Côte D'Ivoire  1857
# 5         25.49  Abidjan  Côte D'Ivoire  1858
# 6         25.92  Abidjan  Côte D'Ivoire  1859
# 7         25.46  Abidjan  Côte D'Ivoire  1860
# 8         25.67  Abidjan  Côte D'Ivoire  1861
# 9         25.17  Abidjan  Côte D'Ivoire  1862
# 10        25.62  Abidjan  Côte D'Ivoire  1873
# 11        25.68  Abidjan  Côte D'Ivoire  1874
# 12        25.25  Abidjan  Côte D'Ivoire  1875
# 13        25.14  Abidjan  Côte D'Ivoire  1876
# 14        25.85  Abidjan  Côte D'Ivoire  1877
# 15        25.87  Abidjan  Côte D'Ivoire  1878
# 16        25.38  Abidjan  Côte D'Ivoire  1879
# 17        25.96  Abidjan  Côte D'Ivoire  1880
# 18        26.07  Abidjan  Côte D'Ivoire  1881
# ...

# %%
dfUK = df1[(df1['country']=='United Kingdom') | (df1['country']=='Global')]
dfUK.head(5)
# Out:
#       avg_temp     city         country  year
# 7652      8.45  Belfast  United Kingdom  1743
# 7653      9.15  Belfast  United Kingdom  1744
# 7654      4.51  Belfast  United Kingdom  1745
# 7655      9.22  Belfast  United Kingdom  1750
# 7656      8.71  Belfast  United Kingdom  1751

# %%
dfUK.to_csv("weather_dataset.csv", index=False, header=True)

# %%
dfBrazil.to_csv("weather_dataset_Brazil.csv", index=False, header=True)
